# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python '/content/drive/MyDrive/SPM_model_train_eval/prediction.py'
# Out:
# 2022-10-11 05:15:26.264042: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# (array([6.093175 , 6.0863514, 6.112736 , 6.1107173, 6.1083803, 6.102905 ,
#        6.1171193, 6.112206 , 6.111542 , 6.1119943, 6.1154785, 6.1145706,
#        6.1116505, 6.112962 , 6.120484 , 6.1202216, 6.1180687, 6.1190085,
#        6.1232343, 6.123838 , 6.123161 , 6.1248703, 6.127305 , 6.1285186,
#        6.128251 , 6.130914 , 6.131828 , 6.1338053, 6.134024 , 6.1369243],
# ...

# %%
# %cd '/content/drive/MyDrive/SPM_model_train_eval'
# Out:
# /content/drive/MyDrive/SPM_model_train_eval

# %%
import os
import tensorflow as tf
import pandas as pd
import numpy as np
# import config
# from utils import evaluate

# %% [markdown]
# # Check model Configurations

# %%
# !cat config.py
# !python config.py

# %% [markdown]
# # Start training

# %%
# !python train.py
# Out:
# data files:  ['GPHISPAT.csv']
# GPU found: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Epoch 1/100
# 105/105 [==============================] - 5s 9ms/step - loss: 0.0061 - accuracy: 0.9546 - val_loss: 0.0145 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 2/100
# 105/105 [==============================] - 1s 5ms/step - loss: 0.0034 - accuracy: 0.9573 - val_loss: 0.0107 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 3/100
# 105/105 [==============================] - 1s 5ms/step - loss: 0.0033 - accuracy: 0.9579 - val_loss: 0.0102 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 4/100
# 105/105 [==============================] - 1s 5ms/step - loss: 0.0032 - accuracy: 0.9603 - val_loss: 0.0107 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 5/100
# 105/105 [==============================] - 1s 5ms/step - loss: 0.0031 - accuracy: 0.9621 - val_loss: 0.0110 - val_accuracy: 1.0000 - lr: 0.0100
# Epoch 6/100
# ...

# %% [markdown]
# # Open Tensorboard to Show Train and Validation logs

# %%
# result_save_path = os.path.join(config.result_dir, config.model_name)
# for data_file in config.data_files:
#   log_dir = os.path.join(result_save_path, "logs_{}_{}".format(config.version, data_file.split('.')[0]))
#   log_train = os.path.join(log_dir, 'train')
#   log_valid = os.path.join(log_dir, 'valid')

#   %load_ext tensorboard

#   %tensorboard --logdir {log_dir}

#   rmse = evaluate()

#   print(rmse)

# %%
# %load_ext tensorboard

# %tensorboard --logdir {log_dir}

# %% [markdown]
# # Test model on test data and show accuracy and confusion matrix

# %%
# from utils import evaluate

# rmse = evaluate()

# print(rmse)
